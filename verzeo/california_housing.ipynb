# %%
from sklearn.datasets import fetch_california_housing
house= fetch_california_housing()

# %%
from keras import layers
x_train[0].shape

# %%
model = keras.Sequential()
#add artif.neurons
model.add(layers.Dense(5,activation = 'relu',input_shape=x_train[0].shape)) #not classi. so using relu
model.add(layers.Dense(1)) #adding 1 neuron in output layer
#6 input columns (6*5)+5*1= 35 parameters
#1 output column (1*5) +1= 6 parameter
    # (input*weights) +bias = parameters

# %%
model.summary()

# %%
model.get_weights()

# %%
model.compile(optimizer = 'adam', loss='mean_squared_error')

# %%
x_train.shape

# %%
# normalized value does not change any
x_train_scaled.shape

# %%
# default batrch size is 32
# 484 values in batrchonce all 484 values
model.fit(x_train_scaled,y_train,epochs=10)

# %%
y_pred = model.predict(x_test_scaled)
y_pred

# %%
y_test #or checking accuracy

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred,y_test)
